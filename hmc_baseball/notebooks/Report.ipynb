# %% [markdown]
# # Aux+Auto DP (AO + ROE): 2024 MLB — Reproducible Results

# %% [markdown]
# This notebook reproduces the key figures and tables from the paper using the production package.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from aux_auto_dp import reproduce_everything

# %%
# Run pipeline (calibration on)
team_df, summary_df = reproduce_everything('data/2024_baseball_stats.csv', output_dir='.', do_calibration=True)
team_df.head()

# %%
# Show summary metrics
summary_df

# %%
# RGB-only scatter plots (generated by the pipeline)
from IPython.display import Image, display
for img in ['scatter_baseline_rgb.png','scatter_calibrated_rgb.png','residuals_baseline_rgb.png','residuals_calibrated_rgb.png','rg_lineplot_rgb.png']:
    display(Image(img))
